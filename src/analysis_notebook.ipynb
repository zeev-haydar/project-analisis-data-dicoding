# %% [markdown]
# # E-Commerce Public Dataset Data Analysis
#
# by: Nazhif Haidar Putra Wibowo

# %% [markdown]
# # Define Business Problem Statement

# %% [markdown]
# The Problem Statements are:
# 1. What products are the most customers want?
# 2. How is the spread of the customers location?

# %% [markdown]
# # Coding

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # IMPORT DATA

# %%
from data import Data

data = Data(data_path="../data/E-Commerce Public Dataset/")

# %% [markdown]
# # EDA

# %% [markdown]
# ## See Data

# %%
print("Data Orders")
display(data.get_data("orders").head())

print ("Data Products")
display(data.get_data("products").head())

print("Data Order Items")
display(data.get_data("order_items").head())
# Out:
# Data Orders
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00
# Data Products
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0
# Data Order Items
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %% [markdown]
# ## Check Null Values

# %%
for key, val in data.get_datas().items():
    print(f"Dataset {key}\n")
    for col in val.columns:
        print(f"Number of null values for column {col} = {val[col].isna().sum()}")
    print("\n====================================\n")
# Out:
# Dataset customers
#
# Number of null values for column customer_id = 0
# Number of null values for column customer_unique_id = 0
# Number of null values for column customer_zip_code_prefix = 0
# Number of null values for column customer_city = 0
# Number of null values for column customer_state = 0
#
# ====================================
#
# Dataset geolocation
#
# Number of null values for column geolocation_zip_code_prefix = 0
# Number of null values for column geolocation_lat = 0
# Number of null values for column geolocation_lng = 0
# Number of null values for column geolocation_city = 0
# Number of null values for column geolocation_state = 0
#
# ====================================
#
# Dataset order_items
#
# Number of null values for column order_id = 0
# Number of null values for column order_item_id = 0
# Number of null values for column product_id = 0
# Number of null values for column seller_id = 0
# Number of null values for column shipping_limit_date = 0
# Number of null values for column price = 0
# Number of null values for column freight_value = 0
#
# ====================================
#
# Dataset order_payments
#
# Number of null values for column order_id = 0
# Number of null values for column payment_sequential = 0
# Number of null values for column payment_type = 0
# Number of null values for column payment_installments = 0
# Number of null values for column payment_value = 0
#
# ====================================
#
# Dataset order_reviews
#
# Number of null values for column review_id = 0
# Number of null values for column order_id = 0
# Number of null values for column review_score = 0
# Number of null values for column review_comment_title = 87656
# Number of null values for column review_comment_message = 58247
# Number of null values for column review_creation_date = 0
# Number of null values for column review_answer_timestamp = 0
#
# ====================================
#
# Dataset orders
#
# Number of null values for column order_id = 0
# Number of null values for column customer_id = 0
# Number of null values for column order_status = 0
# Number of null values for column order_purchase_timestamp = 0
# Number of null values for column order_approved_at = 160
# Number of null values for column order_delivered_carrier_date = 1783
# Number of null values for column order_delivered_customer_date = 2965
# Number of null values for column order_estimated_delivery_date = 0
#
# ====================================
#
# Dataset product_category_name
#
# Number of null values for column product_category_name = 0
# Number of null values for column product_category_name_english = 0
#
# ====================================
#
# Dataset products
#
# Number of null values for column product_id = 0
# Number of null values for column product_category_name = 610
# Number of null values for column product_name_lenght = 610
# Number of null values for column product_description_lenght = 610
# Number of null values for column product_photos_qty = 610
# Number of null values for column product_weight_g = 2
# Number of null values for column product_length_cm = 2
# Number of null values for column product_height_cm = 2
# Number of null values for column product_width_cm = 2
#
# ====================================
#
# Dataset sellers
#
# Number of null values for column seller_id = 0
# Number of null values for column seller_zip_code_prefix = 0
# Number of null values for column seller_city = 0
# Number of null values for column seller_state = 0
#
# ====================================

# %% [markdown]
# ## See products that have the highest orders

# %% [markdown]
# ### Show product name english translation

# %%
product_name = data.get_data("product_category_name")["product_category_name_english"].drop_duplicates()
for i in range(20):
    print(product_name[i])
# Out:
# health beauty
# computers accessories
# auto
# bed bath table
# furniture decor
# sports leisure
# perfumery
# housewares
# telephony
# watches gifts
# food drink
# baby
# stationery
# tablets printing image
# toys
# fixed telephony
# garden tools
# fashion bags accessories
# small appliances
# consoles games

# %% [markdown]
# As you can see, the product name is using the underscore as word separator. It is not looking good for displaying information. Therefore, I replace the underscore with whitespace

# %%
data.get_data("product_category_name")["product_category_name_english"] = data.get_data("product_category_name")["product_category_name_english"].apply(lambda x: x.replace("_", " "))
product_name = data.get_data("product_category_name")["product_category_name_english"].drop_duplicates()
for i in range(20):
    print(product_name[i])
# Out:
# health beauty
# computers accessories
# auto
# bed bath table
# furniture decor
# sports leisure
# perfumery
# housewares
# telephony
# watches gifts
# food drink
# baby
# stationery
# tablets printing image
# toys
# fixed telephony
# garden tools
# fashion bags accessories
# small appliances
# consoles games

# %%
order_items_joined = pd.merge(data.get_data("order_items"), data.get_data("orders"), "inner", on="order_id")
order_item_products = pd.merge(order_items_joined, data.get_data("products"), "inner", "product_id").merge(data.get_data("product_category_name"), "left", "product_category_name")
order_item_products.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value  \
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14
#
#                         customer_id order_status order_purchase_timestamp  \
# 0  3ce436f183e68e07877b285a838db11a    delivered      2017-09-13 08:59:02
# 1  f6dd3ec061db4e3987629fe6b26e5cce    delivered      2017-04-26 10:53:06
# 2  6489ae5e4333f3693df5ad4372dab6d3    delivered      2018-01-14 14:33:31
# 3  d4eb9395c8c0431ee92fce09860c5a06    delivered      2018-08-08 10:00:35
# 4  58dbd0b2d70206bf40e62cd34e84d795    delivered      2017-02-04 13:57:51
#
#    ... order_estimated_delivery_date product_category_name  \
# 0  ...           2017-09-29 00:00:00            cool_stuff
# 1  ...           2017-05-15 00:00:00              pet_shop
# 2  ...           2018-02-05 00:00:00      moveis_decoracao
# 3  ...           2018-08-20 00:00:00            perfumaria
# 4  ...           2017-03-17 00:00:00    ferramentas_jardim
#
#   product_name_lenght product_description_lenght product_photos_qty  \
# 0                58.0                      598.0                4.0
# 1                56.0                      239.0                2.0
# 2                59.0                      695.0                2.0
# 3                42.0                      480.0                1.0
# 4                59.0                      409.0                1.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             650.0               28.0                9.0              14.0
# 1           30000.0               50.0               30.0              40.0
# 2            3050.0               33.0               13.0              33.0
# 3             200.0               16.0               10.0              15.0
# 4            3750.0               35.0               40.0              30.0
#
#    product_category_name_english
# 0                     cool stuff
# 1                       pet shop
# 2                furniture decor
# 3                      perfumery
# 4                   garden tools
#
# [5 rows x 23 columns]

# %%
# order_item_products.info()
data.get_data("product_category_name").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
order_item_counts = order_item_products.value_counts(subset="product_category_name_english").reset_index()
order_item_counts
# Out:
#    product_category_name_english  count
# 0                 bed bath table  11115
# 1                  health beauty   9670
# 2                 sports leisure   8641
# 3                furniture decor   8334
# 4          computers accessories   7827
# ..                           ...    ...
# 66         arts and craftmanship     24
# 67                    la cuisine     14
# 68             cds dvds musicals     14
# 69     fashion childrens clothes      8
# 70         security and services      2
#
# [71 rows x 2 columns]

# %%
top_10_products = order_item_counts.iloc[:10]


fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Bar chart on the first subplot (left)
ax1.set_title("Most Bought Product Categories")
ax1.bar(top_10_products["product_category_name_english"], top_10_products["count"], width=0.8)
ax1.set_xticklabels(top_10_products["product_category_name_english"], rotation=45)
ax1.set_ylabel('Count')

# Pie chart on the second subplot (right)
ax2.set_title("Product Category Distribution")
ax2.pie(top_10_products["count"], 
        labels=top_10_products["product_category_name_english"], 
        autopct='%1.1f%%', startangle=90)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\WINDOWS 10\AppData\Local\Temp\ipykernel_9664\328165251.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(top_10_products["product_category_name_english"], rotation=45)

# %% [markdown]
# Based on the data, "bed bath table" is the most bought product. it accounts for 15.5% of orders

# %% [markdown]
# ## Customer Segmentation by location

# %%
print("Data Customer")
display(data.get_data("customers").head())

print("Data Geolocation")
display(data.get_data("geolocation").head())
# Out:
# Data Customer
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
# Data Geolocation
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
# Since the prefix code in the geolocation table is not unique, 
# I have decided to group the data by city and average the latitude and longitude of the geolocations in each city.
geolocation_mean_lat_and_long = data.get_data("geolocation").groupby("geolocation_city")[["geolocation_lat", "geolocation_lng"]].agg(["mean"])
geolocation_mean_lat_and_long.columns = geolocation_mean_lat_and_long.columns.get_level_values(0)

cust_segs = pd.merge(data.get_data("customers"), geolocation_mean_lat_and_long.reset_index(), "inner", left_on="customer_city", right_on="geolocation_city")
cust_segs.head(10)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# 5  879864dab9bc3047522c92c82e1212b8  4c93744516667ad3b8f1fb645a3116a4
# 6  fd826e7cf63160e536e0908c76c3f441  addec96d2e059c80c30fe6871d30d177
# 7  5e274e7a0c3809e14aba7ad5aae0d407  57b2a98a409812fe9618067b6b8ebe4f
# 8  5adf08e34b2e993982a47070956c5c65  1175e95fb47ddff9de6b2b06188f7e0d
# 9  4b7139f34592b3a31687243a302fa75b  9afe194fb833f79e300e37e580171f22
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
# 5                     89254         jaragua do sul             SC
# 6                      4534              sao paulo             SP
# 7                     35182                timoteo             MG
# 8                     81560               curitiba             PR
# 9                     30575         belo horizonte             MG
#
#         geolocation_city  geolocation_lat  geolocation_lng
# 0                 franca       -20.534057       -47.398437
# 1  sao bernardo do campo       -23.707626       -46.563869
# 2              sao paulo       -23.570860       -46.633242
# 3        mogi das cruzes       -23.530402       -46.193888
# 4               campinas       -22.900861       -47.068536
# 5         jaragua do sul       -26.483921       -49.093460
# 6              sao paulo       -23.570860       -46.633242
# 7                timoteo       -19.553803       -42.638621
# 8               curitiba       -25.453054       -49.274996
# 9         belo horizonte       -19.908772       -43.957549

# %% [markdown]
# ### Group By City and show plot for the spread of customers

# %%
city_counts = cust_segs['customer_city'].value_counts().reset_index()
city_counts.columns = ['customer_city', 'count']
k = 20
city_counts_top_k = city_counts.iloc[:k]

# Set the figure size
plt.figure(figsize=(10, 8))

# Plot horizontal barplot with Seaborn
plt.barh(city_counts_top_k['customer_city'], city_counts_top_k['count'], color='skyblue')

plt.gca().invert_yaxis()

# Set title and labels
plt.title("Customer Count by City")
plt.xlabel("Count")
plt.ylabel("City")

# Display the plot
plt.show()

# %%
state_counts = cust_segs['customer_state'].value_counts().reset_index()
state_counts
# Out:
#    customer_state  count
# 0              SP  41738
# 1              RJ  12842
# 2              MG  11625
# 3              RS   5464
# 4              PR   5036
# 5              SC   3637
# 6              BA   3367
# 7              DF   2140
# 8              ES   2031
# 9              GO   2018
# 10             PE   1651
# 11             CE   1335
# 12             PA    975
# 13             MT    907
# 14             MA    743
# 15             MS    715
# 16             PB    534
# 17             PI    495
# 18             RN    484
# 19             AL    413
# 20             SE    349
# 21             TO    280
# 22             RO    253
# 23             AM    148
# 24             AC     81
# 25             AP     68
# 26             RR     46

# %% [markdown]
# ### Display using world map heatmap (Brazil)

# %%
import geopandas as gpd
gdf = gpd.read_file("../data/brazil/br_shp/br.shp")
state_counts["customer_state_for_map_merge"] = state_counts['customer_state'].apply(lambda x: "BR"+str(x))
print(state_counts)
# Out:
#    customer_state  count customer_state_for_map_merge
# 0              SP  41738                         BRSP
# 1              RJ  12842                         BRRJ
# 2              MG  11625                         BRMG
# 3              RS   5464                         BRRS
# 4              PR   5036                         BRPR
# 5              SC   3637                         BRSC
# 6              BA   3367                         BRBA
# 7              DF   2140                         BRDF
# 8              ES   2031                         BRES
# 9              GO   2018                         BRGO
# 10             PE   1651                         BRPE
# 11             CE   1335                         BRCE
# 12             PA    975                         BRPA
# 13             MT    907                         BRMT
# 14             MA    743                         BRMA
# 15             MS    715                         BRMS
# 16             PB    534                         BRPB
# 17             PI    495                         BRPI
# 18             RN    484                         BRRN
# 19             AL    413                         BRAL
# 20             SE    349                         BRSE
# 21             TO    280                         BRTO
# 22             RO    253                         BRRO
# 23             AM    148                         BRAM
# 24             AC     81                         BRAC
# 25             AP     68                         BRAP
# 26             RR     46                         BRRR

# %%
brazil_map = gdf.merge(state_counts, left_on='id', right_on='customer_state_for_map_merge', how='inner')
# print(brazil_map.isna().sum())

plt.figure(figsize=(16, 16))
ax = brazil_map.plot(column='count', cmap='PuRd', linewidth=1, edgecolor='0.6', legend=True, aspect=1.0)

# Add a title
plt.title('Customer Count by State in Brazil', fontsize=15)
plt.axis('off')

# Annotate state names on the map
for x, y, label, count in zip(brazil_map.geometry.centroid.x, brazil_map.geometry.centroid.y, brazil_map['customer_state_for_map_merge'], brazil_map['count']):
    short_label = label[2:]
    font_color = 'white' if count > brazil_map['count'].quantile(0.97) else 'black'
    ax.annotate(short_label, xy=(x, y), horizontalalignment='center', fontsize=6, color=font_color, weight='bold')

# Show the plot
plt.show()
# Out:
# C:\Users\WINDOWS 10\AppData\Local\Temp\ipykernel_9664\3880776615.py:12: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   for x, y, label, count in zip(brazil_map.geometry.centroid.x, brazil_map.geometry.centroid.y, brazil_map['customer_state_for_map_merge'], brazil_map['count']):

# %% [markdown]
# From the Heatmap above, we can conclude that most of the customers live at the southern state
